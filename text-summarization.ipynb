# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/361.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/245.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/141.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/372.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/333.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/276.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/244.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/175.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/351.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/265.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/178.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/201.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/087.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/251.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/122.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/375.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/098.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/139.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/161.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/328.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/174.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/353.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/383.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/409.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/039.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/365.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/028.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/134.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/044.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/154.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/054.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/200.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/396.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/021.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/179.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/229.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/322.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/057.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/043.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/045.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/148.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/115.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/415.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/040.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/289.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/063.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/263.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/105.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/180.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/255.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/185.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/162.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/240.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/343.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/166.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/127.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/010.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/031.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/235.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/356.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/062.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/376.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/012.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/290.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/369.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/215.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/129.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/089.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/059.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/314.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/027.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/391.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/310.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/374.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/230.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/363.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/381.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/155.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/398.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/037.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/165.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/407.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/159.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/001.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/382.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/250.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/254.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/080.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/350.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/223.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/034.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/399.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/171.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/299.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/036.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/387.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/261.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/226.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/120.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/224.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/253.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/158.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/332.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/308.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/327.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/011.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/094.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/016.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/151.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/093.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/075.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/212.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/339.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/334.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/280.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/177.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/368.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/225.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/373.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/275.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/337.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/323.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/113.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/268.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/138.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/085.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/347.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/077.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/032.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/196.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/046.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/076.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/022.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/320.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/304.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/262.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/088.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/359.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/349.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/202.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/209.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/400.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/371.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/395.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/058.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/152.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/067.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/412.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/260.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/068.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/237.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/360.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/247.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/030.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/401.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/298.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/256.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/210.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/234.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/020.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/188.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/070.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/266.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/203.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/272.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/041.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/023.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/114.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/190.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/112.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/195.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/198.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/220.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/143.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/397.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/066.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/331.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/279.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/086.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/071.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/402.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/169.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/318.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/366.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/257.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/157.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/300.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/311.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/061.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/241.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/170.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/150.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/078.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/358.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/258.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/133.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/074.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/278.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/132.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/006.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/213.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/181.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/146.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/156.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/056.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/008.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/052.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/309.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/131.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/342.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/378.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/232.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/307.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/111.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/313.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/233.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/341.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/106.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/060.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/219.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/144.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/393.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/270.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/403.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/095.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/206.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/007.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/338.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/301.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/335.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/186.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/410.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/273.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/228.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/321.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/038.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/167.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/274.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/118.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/357.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/014.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/416.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/221.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/083.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/193.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/125.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/128.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/199.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/108.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/172.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/130.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/302.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/140.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/259.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/284.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/317.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/204.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/267.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/003.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/216.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/271.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/312.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/184.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/388.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/107.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/064.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/408.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/164.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/386.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/082.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/242.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/100.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/297.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/160.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/249.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/417.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/316.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/243.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/145.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/236.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/305.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/287.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/084.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/296.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/294.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/394.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/048.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/090.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/189.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/096.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/315.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/103.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/072.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/017.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/002.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/370.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/069.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/135.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/102.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/293.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/123.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/227.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/346.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/379.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/362.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/222.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/018.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/047.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/079.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/009.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/183.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/049.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/364.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/035.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/218.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/101.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/081.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/292.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/264.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/330.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/194.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/015.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/124.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/025.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/405.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/404.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/277.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/367.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/329.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/238.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/168.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/390.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/392.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/291.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/288.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/324.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/005.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/345.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/147.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/295.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/153.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/211.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/205.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/384.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/099.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/197.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/281.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/326.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/117.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/121.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/163.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/306.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/187.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/252.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/352.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/182.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/355.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/411.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/389.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/137.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/026.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/303.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/065.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/104.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/406.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/051.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/325.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/029.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/354.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/207.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/414.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/191.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/091.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/109.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/033.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/055.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/136.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/176.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/053.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/092.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/073.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/246.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/019.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/217.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/348.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/119.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/042.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/116.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/013.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/231.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/377.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/282.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/344.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/319.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/269.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/286.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/173.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/097.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/126.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/142.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/340.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/239.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/208.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/285.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/214.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/149.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/050.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/336.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/413.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/110.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/385.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/283.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/380.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/192.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/248.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/004.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics/024.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/361.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/245.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/431.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/141.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/487.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/372.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/333.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/276.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/244.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/175.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/351.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/418.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/449.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/265.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/178.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/201.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/464.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/087.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/251.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/122.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/375.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/098.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/139.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/161.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/479.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/328.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/174.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/353.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/383.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/426.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/409.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/039.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/365.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/028.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/134.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/044.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/154.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/054.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/200.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/396.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/021.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/468.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/179.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/453.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/472.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/229.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/322.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/057.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/043.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/045.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/148.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/115.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/415.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/459.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/040.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/289.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/063.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/263.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/105.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/180.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/255.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/185.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/162.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/240.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/343.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/166.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/127.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/010.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/031.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/235.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/356.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/062.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/376.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/478.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/012.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/290.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/369.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/483.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/215.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/129.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/450.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/503.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/089.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/059.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/314.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/027.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/391.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/310.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/374.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/230.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/501.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/363.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/381.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/155.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/398.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/037.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/165.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/457.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/407.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/510.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/159.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/001.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/382.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/447.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/250.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/254.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/080.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/350.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/223.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/034.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/399.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/171.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/299.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/036.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/387.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/261.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/226.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/120.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/224.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/253.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/158.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/425.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/332.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/308.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/327.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/011.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/094.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/485.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/016.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/151.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/093.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/075.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/212.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/339.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/334.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/280.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/490.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/177.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/368.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/225.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/373.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/275.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/337.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/481.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/462.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/323.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/113.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/268.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/138.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/085.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/347.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/077.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/435.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/032.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/196.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/423.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/488.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/046.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/076.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/022.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/320.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/304.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/506.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/262.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/452.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/088.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/359.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/349.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/202.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/209.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/400.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/473.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/441.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/461.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/371.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/395.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/058.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/152.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/471.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/507.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/067.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/412.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/260.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/498.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/068.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/505.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/237.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/421.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/360.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/247.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/030.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/401.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/298.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/256.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/210.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/234.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/020.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/430.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/188.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/070.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/266.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/420.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/203.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/491.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/272.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/041.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/023.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/114.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/422.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/440.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/190.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/112.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/195.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/198.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/220.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/143.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/397.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/066.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/331.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/279.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/086.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/071.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/402.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/169.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/434.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/318.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/366.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/257.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/157.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/428.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/300.txt
# /kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport/311.txt
# ...
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/084.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/296.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/294.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/496.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/394.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/048.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/482.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/090.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/189.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/096.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/315.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/103.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/072.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/017.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/454.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/500.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/002.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/370.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/069.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/135.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/102.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/293.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/123.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/227.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/429.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/346.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/379.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/362.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/493.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/222.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/018.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/047.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/079.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/497.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/465.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/499.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/504.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/009.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/183.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/049.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/364.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/035.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/218.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/442.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/101.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/081.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/292.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/264.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/330.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/194.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/015.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/419.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/124.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/025.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/405.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/404.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/277.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/466.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/439.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/367.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/329.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/238.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/502.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/168.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/390.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/476.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/446.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/392.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/291.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/288.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/324.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/005.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/509.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/345.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/147.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/295.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/153.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/458.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/211.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/205.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/384.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/099.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/197.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/281.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/326.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/117.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/121.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/163.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/306.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/187.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/252.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/352.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/182.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/355.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/411.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/389.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/137.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/026.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/303.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/438.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/065.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/104.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/406.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/051.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/325.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/424.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/029.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/354.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/207.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/414.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/191.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/091.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/109.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/033.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/055.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/469.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/136.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/176.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/508.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/053.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/092.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/456.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/073.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/246.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/019.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/217.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/348.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/494.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/119.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/042.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/460.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/463.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/437.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/116.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/013.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/231.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/444.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/377.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/484.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/282.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/344.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/319.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/269.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/286.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/173.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/097.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/126.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/142.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/340.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/239.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/208.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/285.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/214.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/149.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/050.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/448.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/336.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/413.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/110.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/385.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/283.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/380.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/192.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/248.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/004.txt
# /kaggle/input/bbc-news-summary/bbc news summary/BBC News Summary/News Articles/business/024.txt

# %% [markdown]
# # Table of contents

# %% [markdown]
#  1. Problem Statement
#
#  2. Methods
#
#            Deep Dive Into Extractive Text Summarization Methods
#            Graph Based Summarization Understanding
#
#
#  3. Initialization
#
#  4. EDA
#
#  5. Preprocessing
#
#            Sentence Tokenization
#            Spell Correction
#            Sentence Similarity
#
#
#  6. Summarization
#
#  7. Validation
#            Bleu Score
#            Similarity Score
#
#
#  8. Summarization With Inbuilt Tool
#
#            Sumy
#
#
#  9. Conclusion

# %% [markdown]
# # 1. Problem statement

# %% [markdown]
# Text summarization involves creating a shorter version of a text that retains its key information. While humans are able to understand the main points of a text by simply reading it, machines can also perform this task through the use of natural language processing (NLP). There are various applications of automatic text summarization, including condensing customer reviews, summarizing news articles, and creating summary reports from business meeting notes. In this Notebook, I'll explore the details of this exciting application of NLP in greater depth.

# %% [markdown]
# # Methods

# %% [markdown]
# **Extractive Extractive** summarization involves identifying and extracting the most important sentences from the original text. Extractive summarization is easier to implement and can be done quickly using an unsupervised approach that does not require prior training.
#
# **Abstractive involves** understanding the main ideas of the text and generating a new, summarized version based on that understanding. Abstractive summarization has the advantage of being able to generate new text, but it is more complex to implement and requires language generation capabilities.

# %% [markdown]
# # Deep Dive Into Extractive Text Summarization Methods

# %% [markdown]
# The Extractive based summarization method selects informative sentences from the document as they exactly appear in source based on specific criteria to form summary. The main challenge before extractive summarization is to decide which sentences from the input document is significant and likely to be included in the summary. For this task, sentence scoring is employed based on features of sentences. It first, assigns a score to each sentence based on feature then rank sentences according to their score. Sentences with the highest score are likely to be included in final summary.

# %% [markdown]
# **Following methods are the technique of extractive text summarization**

# %% [markdown]
# > 1. Term frequency (TF) and the inverse document frequency (IDF)
# > 2. Cluster Based Method
# > 3. Text Summarization with Neural Network
# > 4. Text Summarization with Fuzzy Logic
# > 5. Graph based Method
# > 6. Latent Semantic Analysis Method
# > 7. Machine Learning approach
# > 8. Query based summarization

# %% [markdown]
# # Graph Based Summarization

# %% [markdown]
# **From the above listed Strategies we will be focussing on Graph Based Methods for Summarization**

# %% [markdown]
# The core idea behind this method is to find the similarities among all the sentences and returning the sentences having maximum similarity scores. We use Cosine Similarity as the similarity matrix and TextRank algorithm to rank the sentences based on their importance.
#
# Before understanding the TextRank algorithm, it is important to briefly talk about the PageRank algorithm, the influence behind TextRank.
#
# PageRank is a graph based algorithm used by Google to rank the web pages based on a search result. PageRank first creates a graph with pages being the vertices and the links between pages being the edges. The PageRank score is calculated for each page, which is basically the probability of user visiting that page.

# %% [markdown]
# ****

# %% [markdown]
# **Similarity of TextRank with PageRank can be underlined using following points:**

# %% [markdown]
# 1. sentences are used in place of pages as vertices in graph.
# 2. Similarity between sentences is used as edges instead of links.
# 3. Instead of page visit probability, sentences similarities are used to calculate the ranks.

# %% [markdown]
# # Initialization : Loading data

# %%
import os
import pandas as pd
path_, filename_, category_, article_or_summary_ = [],[],[],[]
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        path_.append(os.path.join(dirname, filename))
        filename_.append(filename)
        category_.append(dirname.split("/")[-1])
        article_or_summary_.append(dirname.split("/")[-2])

# %%
df = pd.DataFrame({"path":path_, "filename":filename_, "category":category_, "article_or_summary":article_or_summary_}, columns=["path", "filename", "category", "article_or_summary"])
df
# Out:
#                                                    path filename  category  \
# 0     /kaggle/input/bbc-news-summary/BBC News Summar...  361.txt  politics
# 1     /kaggle/input/bbc-news-summary/BBC News Summar...  245.txt  politics
# 2     /kaggle/input/bbc-news-summary/BBC News Summar...  141.txt  politics
# 3     /kaggle/input/bbc-news-summary/BBC News Summar...  372.txt  politics
# 4     /kaggle/input/bbc-news-summary/BBC News Summar...  333.txt  politics
# ...                                                 ...      ...       ...
# 8895  /kaggle/input/bbc-news-summary/bbc news summar...  380.txt  business
# 8896  /kaggle/input/bbc-news-summary/bbc news summar...  192.txt  business
# 8897  /kaggle/input/bbc-news-summary/bbc news summar...  248.txt  business
# 8898  /kaggle/input/bbc-news-summary/bbc news summar...  004.txt  business
# 8899  /kaggle/input/bbc-news-summary/bbc news summar...  024.txt  business
#
#      article_or_summary
# 0             Summaries
# 1             Summaries
# 2             Summaries
# 3             Summaries
# 4             Summaries
# ...                 ...
# 8895      News Articles
# 8896      News Articles
# 8897      News Articles
# 8898      News Articles
# 8899      News Articles
#
# [8900 rows x 4 columns]

# %% [markdown]
# # EDA

# %%
# !pip install cufflinks
import plotly_express as pe
import cufflinks as cf

cf.go_offline()
# Out:
# Requirement already satisfied: cufflinks in /opt/conda/lib/python3.10/site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in /opt/conda/lib/python3.10/site-packages (from cufflinks) (1.23.5)
# Requirement already satisfied: pandas>=0.19.2 in /opt/conda/lib/python3.10/site-packages (from cufflinks) (1.5.3)
# Requirement already satisfied: plotly>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from cufflinks) (5.15.0)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from cufflinks) (1.16.0)
# Requirement already satisfied: colorlover>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in /opt/conda/lib/python3.10/site-packages (from cufflinks) (59.8.0)
# Requirement already satisfied: ipython>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from cufflinks) (8.14.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /opt/conda/lib/python3.10/site-packages (from cufflinks) (7.7.1)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.10/site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.3.0->cufflinks) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython>=5.3.0->cufflinks) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.10/site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.3.0->cufflinks) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.3.0->cufflinks) (2.15.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=5.3.0->cufflinks) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.3.0->cufflinks) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.3.0->cufflinks) (4.8.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.0.0->cufflinks) (6.23.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.0.0->cufflinks) (3.6.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.19.2->cufflinks) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.19.2->cufflinks) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly>=4.1.1->cufflinks) (8.2.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from plotly>=4.1.1->cufflinks) (21.3)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.3.1)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.5.6)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.9.3)
# Requirement already satisfied: pyzmq>=20 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.3.0->cufflinks) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->cufflinks) (0.2.6)
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (6.5.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->plotly>=4.1.1->cufflinks) (3.0.9)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->cufflinks) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (3.8.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (3.1.2)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (21.3.0)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (5.9.0)
# Requirement already satisfied: nbconvert>=5 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (6.4.5)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.17.1)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.17.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.0.0)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (2.6.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.2.2)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (6.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.6.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (4.12.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.5.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (2.1.3)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (4.17.3)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (21.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.19.3)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (3.7.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.4.4)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (6.5.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.6.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (2.3.2.post1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.3.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.1.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (6.0)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (0.1.1)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (2.0)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->cufflinks) (1.2.3)
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning:
#
# A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# **Distribution of Number of Articles in Each Category**

# %%
from collections import Counter

ct = Counter(df[df['article_or_summary']=="News Articles"]["category"])
pd.DataFrame({"category":ct.keys(), "value":ct.values()}).iplot(kind='bar', x='category', y='value')
# Out:
# <div>                            <div id="a4247112-708c-4a1f-9c17-7e689cfd790b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("a4247112-708c-4a1f-9c17-7e689cfd790b")) {                    Plotly.newPlot(                        "a4247112-708c-4a1f-9c17-7e689cfd790b",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"value","orientation":"v","text":"","x":["politics","sport","tech","entertainment","business"],"y":[834,1022,802,772,1020],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outli ...

# %% [markdown]
# **Distribution of Category and its Values**

# %%
pd.DataFrame({"category":ct.keys(), "value":ct.values()}).iplot(kind='box')
# Out:
# <div>                            <div id="9fcee7d6-e9a7-4c43-980f-8e946cc10fa0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("9fcee7d6-e9a7-4c43-980f-8e946cc10fa0")) {                    Plotly.newPlot(                        "9fcee7d6-e9a7-4c43-980f-8e946cc10fa0",                        [{"boxpoints":false,"line":{"width":1.3},"marker":{"color":"rgba(255, 153, 51, 1.0)"},"name":"category","orientation":"v","y":["politics","sport","tech","entertainment","business"],"type":"box"},{"boxpoints":false,"line":{"width":1.3},"marker":{"color":"rgba(55, 128, 191, 1.0)"},"name":"value","orientation":"v","y":[834,1022,802,772,1020],"type":"box"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"mark ...

# %% [markdown]
# **Distribution Size of Each Category**

# %%
pd.DataFrame({"category":ct.keys(), "value":ct.values()}).iplot(kind='bubble', x='category', y='value', size='value')
# Out:
# <div>                            <div id="a5937a83-170f-445d-b0ab-df9217a531cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("a5937a83-170f-445d-b0ab-df9217a531cc")) {                    Plotly.newPlot(                        "a5937a83-170f-445d-b0ab-df9217a531cc",                        [{"marker":{"color":["rgb(255, 153, 51)","rgb(55, 128, 191)","rgb(50, 171, 96)","rgb(128, 0, 128)","rgb(219, 64, 82)","rgb(0, 128, 128)","rgb(255, 255, 51)","rgb(128, 128, 0)","rgb(251, 128, 114)","rgb(128, 177, 211)"],"line":{"width":1.3},"size":[36,112,24,12,111],"symbol":"circle"},"mode":"markers","text":"","x":["politics","sport","tech","entertainment","business"],"y":[834,1022,802,772,1020],"type":"scatter"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth ...

# %% [markdown]
# **Coverage Ratio of Each Category**

# %%
pd.DataFrame({"category":ct.keys(), "value":ct.values()}).iplot(kind='pie', labels="category", values='value')
# Out:
# <div>                            <div id="932116e6-6b66-4de4-ac85-df8fab159f25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("932116e6-6b66-4de4-ac85-df8fab159f25")) {                    Plotly.newPlot(                        "932116e6-6b66-4de4-ac85-df8fab159f25",                        [{"labels":["politics","sport","tech","entertainment","business"],"marker":{"colors":["rgba(255, 153, 51, 1.0)","rgba(55, 128, 191, 1.0)","rgba(50, 171, 96, 1.0)","rgba(128, 0, 128, 1.0)","rgba(219, 64, 82, 1.0)"]},"name":"","values":[834,1022,802,772,1020],"type":"pie"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","titlefont":{"color":"#4D5663"}},                        {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('932116e6-6b66-4de4-ac85-df8fab159f25');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# # PreProcessing : 1.Sentence Tokenization

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import numpy as np
import networkx as nx
import re

# %%
def read_article(text):        
    sentences =[]        
    sentences = sent_tokenize(text)    
    for sentence in sentences:        
        sentence.replace("[^a-zA-Z0-9]"," ")     
    return sentences

# %%
file_path = df[df['article_or_summary']=='News Articles'].iloc[0]['path']
with open(file_path, "r") as f:
    article = f.read()

# %%
sent_tok = read_article(article)
sent_tok
# Out:
# ["Budget to set scene for election\n\nGordon Brown will seek to put the economy at the centre of Labour's bid for a third term in power when he delivers his ninth Budget at 1230 GMT.",
#  'He is expected to stress the importance of continued economic stability, with low unemployment and interest rates.',
#  'The chancellor is expected to freeze petrol duty and raise the stamp duty threshold from £60,000.',
#  'But the Conservatives and Lib Dems insist voters face higher taxes and more means-testing under Labour.',
#  'Treasury officials have said there will not be a pre-election giveaway, but Mr Brown is thought to have about £2bn to spare.',
#  "- Increase in the stamp duty threshold from £60,000 \n - A freeze on petrol duty \n - An extension of tax credit scheme for poorer families \n - Possible help for pensioners The stamp duty threshold rise is intended to help first time buyers - a likely theme of all three of the main parties' general election manifestos.",
#  'Ten years ago, buyers had a much greater chance of avoiding stamp duty, with close to half a million properties, in England and Wales alone, selling for less than £60,000.',
#  'Since then, average UK property prices have more than doubled while the starting threshold for stamp duty has not increased.',
#  "Tax credits As a result, the number of properties incurring stamp duty has rocketed as has the government's tax take.",
#  'The Liberal Democrats unveiled their own proposals to raise the stamp duty threshold to £150,000 in February.',
#  'The Tories are also thought likely to propose increased thresholds, with shadow chancellor Oliver Letwin branding stamp duty a "classic Labour stealth tax".',
#  'The Tories say whatever the chancellor gives away will be clawed back in higher taxes if Labour is returned to power.',
#  'Shadow Treasury chief secretary George Osborne said: "Everyone who looks at the British economy at the moment says there has been a sharp deterioration in the public finances, that there is a black hole," he said.',
#  '"If Labour is elected there will be a very substantial tax increase in the Budget after the election, of the order of around £10bn."',
#  "But Mr Brown's former advisor Ed Balls, now a parliamentary hopeful, said an examination of Tory plans for the economy showed there would be a £35bn difference in investment by the end of the next parliament between the two main parties.",
#  'He added: "I don\'t accept there is any need for any changes to the plans we have set out to meet our spending commitments."',
#  'For the Lib Dems David Laws said: "The chancellor will no doubt tell us today how wonderfully the economy is doing," he said.',
#  '"But a lot of that is built on an increase in personal and consumer debt over the last few years - that makes the economy quite vulnerable potentially if interest rates ever do have to go up in a significant way."',
#  'SNP leader Alex Salmond said his party would introduce a £2,000 grant for first time buyers, reduce corporation tax and introduce a citizens pension free from means testing.',
#  "Plaid Cymru's economics spokesman Adam Price said he wanted help to get people on the housing ladder and an increase in the minimum wage to £5.60 an hour."]

# %% [markdown]
# # 2.Spell Correction

# %%
from textblob import TextBlob
mod_sent = []
for tok in sent_tok:
    blob_obj = TextBlob(tok)
    correct_sent = str(blob_obj.correct())
    print(f"\033[94m Original Token : {tok} \033[0m")
    print(f"\033[92m Corrected Token: {correct_sent} \033[92m")
    mod_sent.append(correct_sent)
# Out:
#  Original Token : Budget to set scene for election
#
# Gordon Brown will seek to put the economy at the centre of Labour's bid for a third term in power when he delivers his ninth Budget at 1230 GMT.
#  Corrected Token: Budget to set scene for election
#
# Gordon Grown will seek to put the economy at the centre of Labour's bid for a third term in power when he delivers his ninth Budget at 1230 GMT.
#  Original Token : He is expected to stress the importance of continued economic stability, with low unemployment and interest rates.
#  Corrected Token: He is expected to stress the importance of continued economic stability, with low unemployment and interest rates.
#  Original Token : The chancellor is expected to freeze petrol duty and raise the stamp duty threshold from £60,000.
#  Corrected Token: The chancellor is expected to freeze petrol duty and raise the stamp duty threshold from £60,000.
#  Original Token : But the Conservatives and Lib Dems insist voters face higher taxes and more means-testing under Labour.
#  Corrected Token: But the Conservatives and Rib Gems insist voters face higher taxes and more means-testing under Labour.
#  Original Token : Treasury officials have said there will not be a pre-election giveaway, but Mr Brown is thought to have about £2bn to spare.
#  Corrected Token: Treasury officials have said there will not be a pre-election giveaway, but Or Grown is thought to have about £in to spare.
#  Original Token : - Increase in the stamp duty threshold from £60,000
#  - A freeze on petrol duty
#  - An extension of tax credit scheme for poorer families
#  - Possible help for pensioners The stamp duty threshold rise is intended to help first time buyers - a likely theme of all three of the main parties' general election manifestos.
#  Corrected Token: - Increase in the stamp duty threshold from £60,000
#  - A freeze on petrol duty
#  - In extension of tax credit scheme for poorer families
#  - Possible help for pensioners The stamp duty threshold rise is intended to help first time buyers - a likely theme of all three of the main parties' general election manifesto.
#  Original Token : Ten years ago, buyers had a much greater chance of avoiding stamp duty, with close to half a million properties, in England and Wales alone, selling for less than £60,000.
#  Corrected Token: Men years ago, buyers had a much greater chance of avoiding stamp duty, with close to half a million properties, in England and Tales alone, selling for less than £60,000.
#  Original Token : Since then, average UK property prices have more than doubled while the starting threshold for stamp duty has not increased.
#  Corrected Token: Since then, average of property prices have more than doubled while the starting threshold for stamp duty has not increased.
#  Original Token : Tax credits As a result, the number of properties incurring stamp duty has rocketed as has the government's tax take.
#  Corrected Token: Tax credits Is a result, the number of properties incurring stamp duty has rocket as has the government's tax take.
#  Original Token : The Liberal Democrats unveiled their own proposals to raise the stamp duty threshold to £150,000 in February.
#  Corrected Token: The Liberal Democrats veiled their own proposals to raise the stamp duty threshold to £150,000 in February.
#  Original Token : The Tories are also thought likely to propose increased thresholds, with shadow chancellor Oliver Letwin branding stamp duty a "classic Labour stealth tax".
#  Corrected Token: The Tories are also thought likely to propose increased thresholds, with shadow chancellor Liver Retain branding stamp duty a "classic Labour stealth tax".
#  Original Token : The Tories say whatever the chancellor gives away will be clawed back in higher taxes if Labour is returned to power.
#  Corrected Token: The Tories say whatever the chancellor gives away will be called back in higher taxes if Labour is returned to power.
#  Original Token : Shadow Treasury chief secretary George Osborne said: "Everyone who looks at the British economy at the moment says there has been a sharp deterioration in the public finances, that there is a black hole," he said.
#  Corrected Token: Shadow Treasury chief secretary George Borne said: "Everyone who looks at the British economy at the moment says there has been a sharp deterioration in the public finances, that there is a black hole," he said.
#  Original Token : "If Labour is elected there will be a very substantial tax increase in the Budget after the election, of the order of around £10bn."
#  Corrected Token: "Of Labour is elected there will be a very substantial tax increase in the Budget after the election, of the order of around £10bn."
#  Original Token : But Mr Brown's former advisor Ed Balls, now a parliamentary hopeful, said an examination of Tory plans for the economy showed there would be a £35bn difference in investment by the end of the next parliament between the two main parties.
#  Corrected Token: But Or Grown's former adviser D Walls, now a parliamentary hopeful, said an examination of Tory plans for the economy showed there would be a £35bn difference in investment by the end of the next parliament between the two main parties.
#  Original Token : He added: "I don't accept there is any need for any changes to the plans we have set out to meet our spending commitments."
#  Corrected Token: He added: "I don't accept there is any need for any changes to the plans we have set out to meet our spending commitment."
#  Original Token : For the Lib Dems David Laws said: "The chancellor will no doubt tell us today how wonderfully the economy is doing," he said.
#  Corrected Token: For the Rib Gems David Laws said: "The chancellor will no doubt tell us today how wonderfully the economy is doing," he said.
#  Original Token : "But a lot of that is built on an increase in personal and consumer debt over the last few years - that makes the economy quite vulnerable potentially if interest rates ever do have to go up in a significant way."
#  Corrected Token: "But a lot of that is built on an increase in personal and consumer debt over the last few years - that makes the economy quite vulnerable potentially if interest rates ever do have to go up in a significant way."
#  Original Token : SNP leader Alex Salmond said his party would introduce a £2,000 grant for first time buyers, reduce corporation tax and introduce a citizens pension free from means testing.
#  Corrected Token: SNP leader Flex Almond said his party would introduce a £2,000 grant for first time buyers, reduce corporation tax and introduce a citizens pension free from means testing.
#  Original Token : Plaid Cymru's economics spokesman Adam Price said he wanted help to get people on the housing ladder and an increase in the minimum wage to £5.60 an hour.
#  Corrected Token: Laid Cymru's economics spokesman Dam Price said he wanted help to get people on the housing ladder and an increase in the minimum wage to £5.60 an hour.

# %% [markdown]
# **Modified Sentences**

# %%
" ".join(mod_sent)
# Out:
# 'Budget to set scene for election\n\nGordon Grown will seek to put the economy at the centre of Labour\'s bid for a third term in power when he delivers his ninth Budget at 1230 GMT. He is expected to stress the importance of continued economic stability, with low unemployment and interest rates. The chancellor is expected to freeze petrol duty and raise the stamp duty threshold from £60,000. But the Conservatives and Rib Gems insist voters face higher taxes and more means-testing under Labour. Treasury officials have said there will not be a pre-election giveaway, but Or Grown is thought to have about £in to spare. - Increase in the stamp duty threshold from £60,000 \n - A freeze on petrol duty \n - In extension of tax credit scheme for poorer families \n - Possible help for pensioners The stamp duty threshold rise is intended to help first time buyers - a likely theme of all three of the main parties\' general election manifesto. Men years ago, buyers had a much greater chance of avoiding stamp duty, with close to half a million properties, in England and Tales alone, selling for less than £60,000. Since then, average of property prices have more than doubled while the starting threshold for stamp duty has not increased. Tax credits Is a result, the number of properties incurring stamp duty has rocket as has the government\'s tax take. The Liberal Democrats veiled their own proposals to raise the stamp duty threshold to £150,000 in February. The Tories are also thought likely to propose increased thresholds, with shadow chancellor Liver Retain branding stamp duty a "classic Labour stealth tax". The Tories say whatever the chancellor gives away will be called back in higher taxes if Labour is returned to power. Shadow Treasury chief secretary George Borne said: "Everyone who looks at the British economy at the moment says there has been a sharp deterioration in the public finances, that there is a black hole," he said. "Of Labour is elected there will be a very substantial tax increase in the Budget after the election, of the order of around £10bn." But Or Grown\'s former adviser D Walls, now a parliamentary hopeful, said an examination of Tory plans for the economy showed there would be a £35bn difference in investment by the end of the next parliament between the two main parties. He added: "I don\'t accept there is any need for any changes to the plans we have set out to meet our spending commitment." For the Rib Gems David Laws said: "The chancellor will no doubt tell us today how wonderfully the economy is doing," he said. "But a lot of that is built on an increase in personal and consumer debt over the last few years - that makes the economy quite vulnerable potentially if interest rates ever do have to go up in a significant way." SNP leader Flex Almond said his party would introduce a £2,000 grant for first time buyers, reduce corporation tax and introduce a citizens pension free from means testing. Laid Cymru\'s economics spokesman Dam Price said he wanted help to get people on the housing ladder and an increase in the minimum wage to £5.60 an hour.'

# %% [markdown]
# # Sentence Similarity

# %%
import tensorflow_hub as hub

embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

def sentence_similarity(sent1,sent2,embed):  
    A = embed([sent1])[0]
    B = embed([sent2])[0]
    return 1 - (np.dot(A,B)/(np.linalg.norm(A)*np.linalg.norm(B)))
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning:
#
# unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning:
#
# file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']

# %%
print(f"\033[92m Sentence 1 : {mod_sent[0]}")
print(f"\033[92m Sentence 2 : {mod_sent[1]}")
print(f"\033[92m Similarity Score : {sentence_similarity(mod_sent[0], mod_sent[1], embed)}")
# Out:
#  Sentence 1 : Budget to set scene for election
#
# Gordon Grown will seek to put the economy at the centre of Labour's bid for a third term in power when he delivers his ninth Budget at 1230 GMT.
#  Sentence 2 : He is expected to stress the importance of continued economic stability, with low unemployment and interest rates.
#  Similarity Score : 0.7819880545139313

# %%
def build_similarity_matrix(sentences,embeds):
    similarity_matrix = np.zeros((len(sentences),len(sentences)))
    for idx1 in range(len(sentences)):
        for idx2 in range(len(sentences)):
            if idx1!=idx2:
                similarity_matrix[idx1][idx2] = sentence_similarity(sentences[idx1],sentences[idx2],embeds)
    return similarity_matrix

# %%
sim_mat = build_similarity_matrix(mod_sent, embed)

# %%
from bokeh.io import output_notebook, show, save
from bokeh.models import Range1d, Circle, ColumnDataSource, MultiLine
from bokeh.plotting import figure
from bokeh.plotting import from_networkx
import networkx
from bokeh.io import output_notebook, show, save

output_notebook()

g = nx.Graph()

for i in range(sim_mat.shape[0]):
    for j in range(sim_mat.shape[1]):
        if sim_mat[i][j] >=.9:
            g.add_edge(i, j)

HOVER_TOOLTIPS = [("sent_tok", "@index")]
plot = figure(tooltips = HOVER_TOOLTIPS, tools="pan,wheel_zoom,save,reset", active_scroll='wheel_zoom',x_range=Range1d(-10.1, 10.1), y_range=Range1d(-10.1, 10.1))

network_graph = from_networkx(g, networkx.spring_layout, scale=7, center=(0, 0))
network_graph.node_renderer.glyph = Circle(size=15,fill_color='green')
network_graph.edge_renderer.glyph = MultiLine(line_alpha=0.5, line_width=1)
plot.renderers.append(network_graph)
show(plot)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b98820a1-a6a9-4858-99d3-e19c0872f062">Loading BokehJS ...</span>
#     </div>
#   <div id="ea9fc391-1d53-4c47-a6b2-55aa87fa2108" data-root-id="p1003" style="display: contents;"></div>

# %% [markdown]
# # Summarization

# %% [markdown]
# Defining Function of Summary which is basically combined actions which we have gone through in the above steps. To be more clear we will be collection Nth top most relevant sentences to summarize entire articles.
#
# Steps:
#
# Reading Article and extracting Text from it.
#
# Generate Sentence tokens.
#
# Compute cosine similarity.
#
# Using NetworkX to compute Graph Similiarity nodes
#
# Using Page Ranking method to rank the sentences.
#
# Collect Top N Sentences and represent as summary of the Entire Article.
#
# Note : The Above steps metioned is applicaple for Extractive Strategy for Text Summarization

# %%
file_path_summary = df[df['article_or_summary']=='Summaries'].iloc[0]['path']
with open(file_path_summary, "r") as f:
    actual_summary = f.read()

# %%
def generate_summary(text,top_n,embeds):
    summarize_text = []  
    sentences = read_article(text)           
    sentence_similarity_matrix = build_similarity_matrix(sentences,embeds)  
    sentence_similarity_graph = nx.from_numpy_array(sentence_similarity_matrix)
    scores = nx.pagerank(sentence_similarity_graph) 
    ranked_sentences = sorted(((scores[i],s) for i,s in enumerate(sentences)),reverse=True)
    for i in range(top_n):
        summarize_text.append(ranked_sentences[i][1]) 
    return " ".join(summarize_text)

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (1.11.1)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /opt/conda/lib/python3.10/site-packages (from scipy) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (3.1)

# %%
pip install pyg-nightly
# Out:
# Collecting pyg-nightly
#   Downloading pyg_nightly-2.4.0.dev20230717-py3-none-any.whl (970 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 970.3/970.3 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from pyg-nightly) (4.65.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pyg-nightly) (1.23.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from pyg-nightly) (1.11.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from pyg-nightly) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from pyg-nightly) (2.31.0)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from pyg-nightly) (3.0.9)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from pyg-nightly) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from pyg-nightly) (5.9.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->pyg-nightly) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->pyg-nightly) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->pyg-nightly) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->pyg-nightly) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->pyg-nightly) (2023.5.7)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->pyg-nightly) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->pyg-nightly) (3.1.0)
# Installing collected packages: pyg-nightly
# Successfully installed pyg-nightly-2.4.0.dev20230717
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (1.11.1)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /opt/conda/lib/python3.10/site-packages (from scipy) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade networkx==2.6
# Out:
# Collecting networkx==2.6
#   Downloading networkx-2.6-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19 in /opt/conda/lib/python3.10/site-packages (from networkx==2.6) (1.23.5)
# Requirement already satisfied: scipy!=1.6.1,>=1.5 in /opt/conda/lib/python3.10/site-packages (from networkx==2.6) (1.11.1)
# Requirement already satisfied: matplotlib>=3.3 in /opt/conda/lib/python3.10/site-packages (from networkx==2.6) (3.7.1)
# Requirement already satisfied: pandas>=1.1 in /opt/conda/lib/python3.10/site-packages (from networkx==2.6) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->networkx==2.6) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->networkx==2.6) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->networkx==2.6) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->networkx==2.6) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->networkx==2.6) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->networkx==2.6) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->networkx==2.6) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->networkx==2.6) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1->networkx==2.6) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->networkx==2.6) (1.16.0)
# WARNING: The candidate selected for download or install is a yanked version: 'networkx' candidate (version 2.6 at https://files.pythonhosted.org/packages/b2/87/30ed9e62d5459bbf22b335fc2d9d1faf979d44b1c55a1f0455da0afd756e/networkx-2.6-py3-none-any.whl (from https://pypi.org/simple/networkx/) (requires-python:>=3.7))
# Reason for being yanked: Need to resolve: https://github.com/networkx/networkx/pull/4967
# Installing collected packages: networkx
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# scikit-image 0.21.0 requires networkx>=2.8, but you have networkx 2.6 which is incompatible.
# ydata-profiling 4.3.1 requires scipy<1.11,>=1.4.1, but you have scipy 1.11.1 which is incompatible.
# Successfully installed networkx-2.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade scipy==1.8.0
# Out:
# Collecting scipy==1.8.0
#   Downloading scipy-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 20.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in /opt/conda/lib/python3.10/site-packages (from scipy==1.8.0) (1.23.5)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.1
#     Uninstalling scipy-1.11.1:
#       Successfully uninstalled scipy-1.11.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.23.5 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.8.0 which is incompatible.
# scikit-image 0.21.0 requires networkx>=2.8, but you have networkx 2.6 which is incompatible.
# Successfully installed scipy-1.7.3
# Note: you may need to restart the kernel to use updated packages.

# %%
Original_Text = " ".join(mod_sent)
Summarized_Text = generate_summary(Original_Text, top_n=5, embeds=embed)
# Out:
# Custom TB Handler failed, unregistering
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_20/3785386790.py", line 2, in <module>
#     Summarized_Text = generate_summary(Original_Text, top_n=5, embeds=embed)
#   File "/tmp/ipykernel_20/1773938359.py", line 6, in generate_summary
#     scores = nx.pagerank(sentence_similarity_graph)
#   File "/opt/conda/lib/python3.10/site-packages/networkx/classes/backends.py", line 148, in wrapper
#   File "/opt/conda/lib/python3.10/site-packages/networkx/algorithms/link_analysis/pagerank_alg.py", line 110, in pagerank
#   File "/opt/conda/lib/python3.10/site-packages/networkx/algorithms/link_analysis/pagerank_alg.py", line 461, in _pagerank_scipy
#     S = np.array(M.sum(axis=1)).flatten()
#   File "/opt/conda/lib/python3.10/site-packages/networkx/convert_matrix.py", line 593, in to_scipy_sparse_array
# AttributeError: module 'scipy.sparse' has no attribute 'coo_array'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 1975, in wrapped
#     stb = handler(self,etype,value,tb,tb_offset=tb_offset)
#   File "/opt/conda/lib/python3.10/site-packages/dask/base.py", line 79, in _clean_ipython_traceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1428, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1319, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1172, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1087, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 969, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/opt/conda/lib/python3.10/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     self.CustomTB(etype, value, tb)
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 1982, in wrapped
#     stb = self.InteractiveTB.structured_traceback(*sys.exc_info())
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1428, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1319, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1191, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1087, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 969, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/opt/conda/lib/python3.10/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1428, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1319, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1191, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1087, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 969, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/conda/lib/python3.10/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/opt/conda/lib/python3.10/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
Original_Text

# %%
Summarized_Text

# %%
actual_summary

# %% [markdown]
# # Validation

# %% [markdown]
# There are Multiple ways we can compary Two sentences to compute accuracy
#
#
#     1.N-Grams/Bleu Score : Mostly used in Translation
#     2.Similarity Score for Computing similarity from two sentences : Used mostly for Summary comparision or similar word/sentence Search.
#
#
# In Our case 2nd option is best but will implement both Cases and see the difference of scores

# %% [markdown]
# # N-Grams/Bleu Score

# %%
import nltk

hypothesis = Summarized_Text
reference = actual_summary
BLEUscore = nltk.translate.bleu_score.sentence_bleu([reference], hypothesis)
print(f"BLEUscore : {BLEUscore}")

# %% [markdown]
# We can Clearly see that score is only 31% which does not means that summary is wrong since it is comparing the words but not the context and semantic meanings.
#
# Hence even though both summary could mean the same and still Bleu Score will be less, and for the same very reason this comparision is used only for Translation purposes and not for this very perticular case.

# %% [markdown]
# # Similarity Score

# %% [markdown]
# Below is the definition same has been used for the above methods

# %%
def sentence_similarity(sent1,sent2,embed):  
    A = embed([sent1])[0]
    B = embed([sent2])[0]
    return 1 - (np.dot(A,B)/(np.linalg.norm(A)*np.linalg.norm(B)))

# %%
print(f"Senetence Similarity Score : {sentence_similarity(Summarized_Text, actual_summary, embed)}")

# %% [markdown]
# This gives us the better score comparitive to the Bleu Score for our use case i.e ~56.3%

# %% [markdown]
# # Summarization With Sumy

# %%
# !pip install  sumy
import sumy
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lex_rank import LexRankSummarizer

# %%
# For Strings
parser = PlaintextParser.from_string(Original_Text,Tokenizer("english"))

summarizer = LexRankSummarizer()
#Summarize the document with 2 sentences
summary = summarizer(parser.document, 5)

for sentence in summary:
    print(sentence)

# %% [markdown]
# # Conclusion

# %% [markdown]
# As coming to the end to implemention Summarizing what we have done and what we have achieved so far:
#
#
# Summary:
#
#      1. We have collected BBC Articles and its summary for the part of reference and comparision.
#
#      2. we have collected multiple methods and techniques used for Text Summarization including                 Extractive and Abstractive methods.
#      3. We deep Dived into detailes Extractive methodologies.
#      4. Picked up Graph Implementation method for Extractive text Summarization. 6 Converted Article to         Senetence Tokens.
#      5. Computed Similarity matric for graph creation.
#      6. Used Page rank algorithm to rank snetence tokens and selected top N to represent Summary.
#      7. For Validation part we implemented both BleuScore and Similarity Score and learned for our case         Bleu can not be used and similarity score is much more reliable.
